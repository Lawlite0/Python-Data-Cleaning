# %%
#to get dates from strings and replace them in satndard format

str_test = "hello this is 07- 09-1998 my 02-28-1997 birthdate 10th June,1998 and 2000-07 - 12 my friend's birthdate is 2009-03 - 03 and xyz  and 03 31-1998"
# test = "the date is 23/4/1998"

# str_test = "hello this April,is my birthdate 10th June,1998 and 02-11-98 my friend's birthdate is 2009-3-13 and xyz 1999 - 5-9 and 03 31-1998"
# regex = [ 
    
#             #DD(th) MMMM,YYYY
#             '\d{1,2}\s*((rd)|(th)|(st)(nd))\s*((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december)),?\s*?\d{4}',
            
#             #DD(th) MMMM,YY
#             '\d{1,2}\s*((rd)|(th)|(st)(nd))\s*((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december)),?\s*?\d{1,2}((\s)|$)',
    
#             #DD/MMM/YYYY DD MMM YYYY
#             '\d{1,2}\s*[/. -]\s*((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december))\s*[/. -]\s*\d{4}',
            
#             #DD/MMM/YY DD MMM YY
#             '\d{1,2}\s*[/. -]\s*((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december))\s*[/. -]\s*\d{1,2}((\s)|$)',
    
#             #MMM/YYYY
#             '((\s)|^)((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december))\s*[/. -]\s*\d{4}',
            
#             #MMM/YY
#             '((\s)|^)((Jan)|(jan)|(January)|(january)|(Feb)|(feb)|(February)|(february)|(Mar)|(mar)|(March)|(march)|(Apr)|(apr)|(April)|(april)|(May)|(may)|(Jun)|(jun)|(June)|(june)|(Jul)|(jul)|(July)|(july)|(Aug)|(aug)|(August)|(august)|(Sep)|(sep)|(September)|(september)|(Oct)|(oct)|(October)|(october)|(Nov)|(nov)|(November)|(november)|(Dec)|(dec)|(December)|(december))\s*[/. -]\s*\d{1,2}((\s)|$)',
        
    
#             #dd/mm/yyyy  dd mm yyyy
#             '\d{1,2}\s*[/. -]\s*\d{1,2}\s*[/. -]\s*\d{4}',
    
#             #dd/mm/yy yy/mm/dd  dd mm yy
#             '((\s)|(^))\d{1,2}\s*[/. -]\s*\d{1,2}\s*[/. -]\s*\d{1,2}((\s)|$)',
#         ]
# test_str = " 20 apr 1998"
# dates_list=[]
# for reg in regex:
#     for match in re.finditer(reg, test_str):
#         print(reg)
#         dates_list.append(match.group())

# dates_list
# # dates_list=pd.to_datetime("2012/02/29")
# dates_list = pd.to_datetime(dates_list)
# dates_list
# # # dates_start_end
# # # dates_start_end_arr = np.asarray(dates_start_end)
# # # x = dates_start_end_arr[:,0]
# # # x
# # # dates_list = pd.to_datetime(dates_list, dayfirst= True)
# # dates_list
# # # [i[0] for i in dates_start_end]
# # # def replace(dates_start_end, str):

# # new_str = str_test

# # count=int(0)
# # for mylist in dates_start_end:
# #     new_str = new_str.replace(dates_list[count],mylist[0].strftime('%Y-%m-%d'),1)
# # #     print(dates_list[count])
# #     count = count + 1
# #     print(new_str)
# # #     print(mylist[1])
# #     new_str = new_str[:mylist[1]]+mylist[0].strftime('%Y-%m-%d')+new_str[mylist[2]:]
